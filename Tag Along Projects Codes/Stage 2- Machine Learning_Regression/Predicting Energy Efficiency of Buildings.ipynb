# %% [markdown]
# ### IMPORT NECESSARY LIBRARIES

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# Set warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### LOAD DATASET

# %%
df = pd.read_csv(r"C:\Users\Black Concept\WorkSpace\HAMOYE TAG ALONG CODES\HAMOYE--TAG-ALONG-CODES\Tag Along Projects Codes\Stage 2- Machine Learning_Regression\energydata_complete.csv")

# %% [markdown]
# ### EXPLORE DATASET

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %% [markdown]
# ### DATA PREPROCESSING

# %%
# Check for missing values
df.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
# Check to confirm the encoding made
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %% [markdown]
# ### QUESTION 17
# From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius (x=T2) and the temperature outside the building (y=T6). What is the Root Mean Squared Error in three D.P.?

# %%
# Split the dataset into target and features

# dependent variable
y = df['T6']

# independent variables
x = df[['T2']]

# Split the features and targets into training and test
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# Select model
model = LinearRegression()

# Fit Model
model.fit(x_train,y_train)

# Predict the target values for the features dataset
y_prediction = model.predict(x_test)

# Evaluate the model using r_squared
r2_score = round(mean_squared_error(y_test, y_prediction, squared=False),3)

print(f'The Root Mean Squared Error is: {r2_score}')
# Out:
# The Root Mean Squared Error is: 3.633

# %% [markdown]
# ### QUESTION 18
# Remove the following columns: [“date”, “lights”]. The target variable is “Appliances”. Use a 70-30 train-test set split with a  random state of 42 (for reproducibility). Normalize the dataset using the MinMaxScaler (Hint: Use the MinMaxScaler fit_transform and transform methods on the train and test set respectively). Run a multiple linear regression using the training set.

# %%
# Drop specified columns and set target variable
df2 = df.drop(columns=["date", "lights"])
x2 = df2.drop(columns=["Appliances"])
y2 = df2["Appliances"]

# Split the dataset into train and test
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.3, random_state=42)

# Normalize the dataset using MinMaxScaler
scaler = MinMaxScaler()
x2_train_scaled = scaler.fit_transform(x2_train)
x2_test_scaled = scaler.transform(x2_test)

# Train a multiple linear regression model
model = LinearRegression()
model.fit(x2_train_scaled, y2_train)

# Predict on the test set
y_prediction2 = model.predict(x2_test_scaled)

# Model evaluation
mse = round((mean_absolute_error(y2_test, y_prediction2)),3)
print("Mean Absolute Error:", mse)
# Out:
# Mean Absolute Error: 53.641

# %% [markdown]
# ### QUESTION 19
# What is the Root Mean Squared Error (in three decimal places) for the training set?

# %%
# Predict on the training set
y_train_prediction = model.predict(x2_train_scaled)

# Calculate Mean Squared Error (MSE) for training set
mse_train = mean_squared_error(y2_train, y_train_prediction)

# Calculate Root Mean Squared Error (RMSE) for training set
rmse_train = round((mse_train ** 0.5), 3)

print(f'The Root Mean Squared Error is: {rmse_train}')
# Out:
# The Root Mean Squared Error is: 95.216

# %% [markdown]
# ### QUESTION 20
# What is the Mean Absolute Error (in three decimal places) for test set?

# %%
# Mean Absolute Error (MAE)
mae = round((mean_absolute_error(y2_test, y_prediction2)),3)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 53.641

# %% [markdown]
# ### QUESTION 21
# What is the Root Mean Squared Error (in three decimal places) for test set?

# %%
# Predict on the training set
y_train_prediction3 = model.predict(x2_train_scaled)

# Calculate Mean Squared Error (MSE) for training set
mse_train = mean_squared_error(y2_train, y_train_prediction3)

# Calculate RMSE for training set
rmse_test2 = round((mse_train ** 0.5),3)

print(f'The Root Mean Squared Error is: {rmse_test2}')
# Out:
# The Root Mean Squared Error is: 95.216

# %% [markdown]
# ### QUESTION 22
# Did the Model above overfit to the training set

# %%
if rmse_train < rmse_test2:
    print("There may be overfitting.")
else:
    print("The model did not.")
# Out:
# The model did not.

# %% [markdown]
# ### QUESTION 23
# Train a ridge regression model with default parameters. Is there any change to the root mean squared error (RMSE) when evaluated on the test set?

# %%
ridge_model = Ridge()

# Fit the Ridge model on the scaled training data
ridge_model.fit(x2_train_scaled, y2_train)

# Predict on the test set using the Ridge model
y_prediction_ridge = ridge_model.predict(x2_test_scaled)

# Calculate Root Mean Squared Error (RMSE) for Ridge model on test set
rmse_test_ridge = round((mean_squared_error(y2_test, y_prediction_ridge, squared=False)),3)

# Check if there is a change compared to the test set
if rmse_test_ridge < rmse_test2:
    print(f"Yes, there is a difference, the RMSE for ridge regression is {rmse_test_ridge} while that of the test is {rmse_test2}")
else:
    print("No, there is no difference")
# Out:
# Yes, there is a difference, the RMSE for ridge regression is 93.709 while that of the test is 95.216

# %% [markdown]
# ### QUESTION 24
# Train a lasso regression model with default value and obtain the new feature weights with it. How many of the features have non-zero feature weights?

# %%
lasso_model = Lasso()

# Fit the Lasso model on the scaled training data
lasso_model.fit(x2_train_scaled, y2_train)

# Obtain feature weights (coefficients) from the Lasso model
feature_weights = lasso_model.coef_

# Count number of features with non-zero weights
nonzero_features = np.sum(feature_weights != 0)

print("Number of features with non-zero weights:", num_nonzero_features)
# Out:
# Number of features with non-zero weights: 4

# %% [markdown]
# ### QUESTION 25
# What is the new RMSE with the Lasso Regression on the test set?

# %%
# Train a Lasso regression model
lasso_model = Lasso()

# Fit the Lasso model on the scaled training data
lasso_model.fit(x2_train_scaled, y2_train)

# Predict on the test set using the Lasso model
y_prediction_lasso = lasso_model.predict(x2_test_scaled)

# Calculate Root Mean Squared Error (RMSE) for Lasso model on test set
rmse_test_lasso = mean_squared_error(y2_test, y_prediction_lasso, squared=False)

print(f'The Root Mean Squared Error is: {rmse_test_lasso}')
# Out:
# The Root Mean Squared Error is: 99.42422892589771
